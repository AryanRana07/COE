# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('winequality-red.csv')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 0               7.4             0.700         0.00             1.9      0.076  \
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Fill missing values with mean
data = data.fillna(data.mean())

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 0            7.4              0.70         0.00             1.9      0.076  \
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 0                 11.0                  34.0   0.9978  3.51       0.56  \
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Create a new column for average acidity
data['avg_acidity'] = (data['fixed acidity'] + data['volatile acidity']) / 2

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 0            7.4              0.70         0.00             1.9      0.076  \
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 0                 11.0                  34.0   0.9978  3.51       0.56  \
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  avg_acidity
# 0      9.4        5         4.05
# ...

# %%
# Delete the columns 'fixed acidity' and 'volatile acidity'
data = data.drop(['fixed acidity', 'volatile acidity'], axis=1)

# %%
data.head()
# Out:
#    citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0         0.00             1.9      0.076                 11.0
# 1         0.00             2.6      0.098                 25.0
# 2         0.04             2.3      0.092                 15.0
# 3         0.56             1.9      0.075                 17.0
# 4         0.00             1.9      0.076                 11.0
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality  \
# 0                  34.0   0.9978  3.51       0.56      9.4        5
# 1                  67.0   0.9968  3.20       0.68      9.8        5
# 2                  54.0   0.9970  3.26       0.65      9.8        5
# 3                  60.0   0.9980  3.16       0.58      9.8        6
# 4                  34.0   0.9978  3.51       0.56      9.4        5
#
#    avg_acidity
# 0         4.05
# 1         4.34
# 2         4.28
# 3         5.74
# 4         4.05

# %%
# Drop duplicate rows
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1359 entries, 0 to 1598
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   citric acid           1359 non-null   float64
#  1   residual sugar        1359 non-null   float64
#  2   chlorides             1359 non-null   float64
#  3   free sulfur dioxide   1359 non-null   float64
#  4   total sulfur dioxide  1359 non-null   float64
#  5   density               1359 non-null   float64
#  6   pH                    1359 non-null   float64
#  7   sulphates             1359 non-null   float64
#  8   alcohol               1359 non-null   float64
#  9   quality               1359 non-null   int64
#  10  avg_acidity           1359 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 127.4 KB

# %%
# Print first 20 rows
print(data.head(20))
# Out:
#     citric acid  residual sugar  chlorides  free sulfur dioxide
# 0          0.00             1.9      0.076                 11.0  \
# 1          0.00             2.6      0.098                 25.0
# 2          0.04             2.3      0.092                 15.0
# 3          0.56             1.9      0.075                 17.0
# 4          0.00             1.9      0.076                 11.0
# 5          0.00             1.8      0.075                 13.0
# 6          0.06             1.6      0.069                 15.0
# 7          0.00             1.2      0.065                 15.0
# 8          0.02             2.0      0.073                  9.0
# 9          0.36             6.1      0.071                 17.0
# 10         0.08             1.8      0.097                 15.0
# 11         0.36             6.1      0.071                 17.0
# 12         0.00             1.6      0.089                 16.0
# 13         0.29             1.6      0.114                  9.0
# ...

# %%
print(data.tail(6))
# Out:
#       citric acid  residual sugar  chlorides  free sulfur dioxide
# 1593         0.08             1.9      0.068                 28.0  \
# 1594         0.08             2.0      0.090                 32.0
# 1595         0.10             2.2      0.062                 39.0
# 1596         0.13             2.3      0.076                 29.0
# 1597         0.12             2.0      0.075                 32.0
# 1598         0.47             3.6      0.067                 18.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 1593                  38.0  0.99651  3.42       0.82      9.5        6  \
# 1594                  44.0  0.99490  3.45       0.58     10.5        5
# 1595                  51.0  0.99512  3.52       0.76     11.2        6
# 1596                  40.0  0.99574  3.42       0.75     11.0        6
# 1597                  44.0  0.99547  3.57       0.71     10.2        5
# 1598                  42.0  0.99549  3.39       0.66     11.0        6
#
# ...
