# %%
def commonVal(nums1, nums2):
    s1 = set(nums1)
    s2 = set(nums2)

    intersect = s1.intersection(s2)
    result = list(intersect)
    return result

nums1 = [1, 2, 2, 1]
nums2 = [2, 2]

output = commonVal(nums1, nums2)
print(output)
# Out:
# [2]
